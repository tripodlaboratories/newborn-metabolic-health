# %% [markdown]
# # Correlation Disruption Commonalities
# Determining the correlation pairs that perform the most similarly across outcomes.
# Should also examine the outcome-specific correlation disruption pairs as well?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from statsmodels.stats.multitest import multipletests
import seaborn as sns

# %%
nb_save_prefix = "0.0.3-metabolic_corr_disrupt_stats"

# %%
corr_df = pd.read_csv("../results/correlation_disruption_networks_edges.csv")

# %%
corr_df
# Out:
#     metabolite_from       metabolite_to  case_spearman_rho     case_pval  \
# 0           ARG/ORN                 OXP           0.100741  6.149821e-11
# 1              C-10                 ARG           0.114193  1.166276e-13
# 2            C-12:1                 ARG           0.076605  6.834579e-07
# 3              C-16                 C-5           0.005384  7.275618e-01
# 4          C-8/C-10                 PHE          -0.002837  8.543761e-01
# ..              ...                 ...                ...           ...
# 99          PHE/TYR  FC/(C-16 + C-18:1)          -0.017385  1.887169e-01
# 100             TYR              C-18:1          -0.035964  6.529541e-03
# 101             VAL               C14:1           0.010213  4.400463e-01
# 102             XLE                C-16           0.012015  3.637084e-01
# 103             XLE             PHE/TYR          -0.002342  8.594474e-01
#
#      case_log10_pval  control_spearman_rho  control_pval  control_log10_pval  \
# 0          10.211138             -0.024086  1.097661e-01            0.959532
# 1          12.933199             -0.007928  5.986706e-01            0.222812
# 2           6.165288             -0.004699  7.550614e-01            0.122018
# 3           0.138130             -0.116305  8.762844e-15           14.057355
# 4           0.068351              0.053265  4.010653e-04            3.396785
# ..               ...                   ...           ...                 ...
# 99          0.724189              0.127542  1.690714e-17           16.771930
# 100         2.185117              0.005272  7.263622e-01            0.138847
# 101         0.356502             -0.083516  2.741576e-08            7.562000
# 102         0.439247             -0.098130  6.342991e-11           10.197706
# 103         0.065781              0.113119  4.637352e-14           13.333730
#
#      metabolite_pair_label  rho_diff  abs_rho_diff outcome
# 0                      NaN  0.076655      0.124827     BPD
# 1                      NaN  0.106265      0.122121     BPD
# 2                      NaN  0.071905      0.081304     BPD
# 3                      NaN -0.110921      0.121689     BPD
# 4                      NaN  0.050429      0.056102     BPD
# ..                     ...       ...           ...     ...
# 99                     NaN  0.110157      0.144927     ROP
# 100                    NaN -0.030692      0.041235     ROP
# 101                    NaN -0.073303      0.093729     ROP
# 102                    NaN -0.086115      0.110145     ROP
# 103                    NaN  0.110777      0.115462     ROP
#
# [104 rows x 12 columns]

# %%
# Append case and control numbers from metadata
outcome_labels = {
    'bpd_any': 'BPD',
    'ivh_any': 'IVH',
    'nec_any': 'NEC',
    'rop_any': 'ROP'
}

metab_outcomes = pd.read_csv("../data/processed/neonatal_conditions.csv").set_index("row_id")
meta = pd.read_csv("../data/processed/metadata.csv", low_memory=False)
meta = meta.set_index("row_id")
cohort_preterm_ga = [
    "22_23",
    "24_25",
    "26_27",
    "28_29",
]
preterm_ids = meta.query("gacat in @cohort_preterm_ga").index
preterm_cohort_meta = meta.loc[preterm_ids]
preterm_outcomes = metab_outcomes.loc[preterm_ids, list(outcome_labels.keys())]

# %%
preterm_outcomes
# Out:
#         bpd_any  ivh_any  nec_any  rop_any
# row_id
# 1             1        0        0        0
# 5             0        0        0        1
# 6             0        0        0        1
# 11            0        1        0        1
# 13            0        0        0        1
# ...         ...      ...      ...      ...
# 41396         0        0        0        0
# 41397         0        0        0        0
# 41400         1        0        0        0
# 41405         0        0        1        0
# 41406         1        1        0        1
#
# [13536 rows x 4 columns]

# %%
preterm_counts = preterm_outcomes.melt(var_name="outcome", value_name="status").groupby(
    ["outcome", "status"]
).size().reset_index().pivot(
    index="outcome", columns="status", values=0
).rename(
    columns={0: "control_n", 1: "case_n"}
).rename(
    index=outcome_labels
).reset_index()
preterm_counts.columns.name = None
preterm_counts
# Out:
#   outcome  control_n  case_n
# 0     BPD       9347    4189
# 1     IVH       9276    4260
# 2     NEC      12097    1439
# 3     ROP       7818    5718

# %%
corr_df_counts = pd.merge(corr_df, preterm_counts, left_on="outcome", right_on="outcome", how="left")
corr_df_counts
# Out:
#     metabolite_from       metabolite_to  case_spearman_rho     case_pval  \
# 0           ARG/ORN                 OXP           0.100741  6.149821e-11
# 1              C-10                 ARG           0.114193  1.166276e-13
# 2            C-12:1                 ARG           0.076605  6.834579e-07
# 3              C-16                 C-5           0.005384  7.275618e-01
# 4          C-8/C-10                 PHE          -0.002837  8.543761e-01
# ..              ...                 ...                ...           ...
# 99          PHE/TYR  FC/(C-16 + C-18:1)          -0.017385  1.887169e-01
# 100             TYR              C-18:1          -0.035964  6.529541e-03
# 101             VAL               C14:1           0.010213  4.400463e-01
# 102             XLE                C-16           0.012015  3.637084e-01
# 103             XLE             PHE/TYR          -0.002342  8.594474e-01
#
#      case_log10_pval  control_spearman_rho  control_pval  control_log10_pval  \
# 0          10.211138             -0.024086  1.097661e-01            0.959532
# 1          12.933199             -0.007928  5.986706e-01            0.222812
# 2           6.165288             -0.004699  7.550614e-01            0.122018
# 3           0.138130             -0.116305  8.762844e-15           14.057355
# 4           0.068351              0.053265  4.010653e-04            3.396785
# ..               ...                   ...           ...                 ...
# 99          0.724189              0.127542  1.690714e-17           16.771930
# 100         2.185117              0.005272  7.263622e-01            0.138847
# 101         0.356502             -0.083516  2.741576e-08            7.562000
# 102         0.439247             -0.098130  6.342991e-11           10.197706
# 103         0.065781              0.113119  4.637352e-14           13.333730
#
#      metabolite_pair_label  rho_diff  abs_rho_diff outcome  \
# 0                      NaN  0.076655      0.124827     BPD
# 1                      NaN  0.106265      0.122121     BPD
# 2                      NaN  0.071905      0.081304     BPD
# 3                      NaN -0.110921      0.121689     BPD
# 4                      NaN  0.050429      0.056102     BPD
# ..                     ...       ...           ...     ...
# 99                     NaN  0.110157      0.144927     ROP
# 100                    NaN -0.030692      0.041235     ROP
# 101                    NaN -0.073303      0.093729     ROP
# 102                    NaN -0.086115      0.110145     ROP
# 103                    NaN  0.110777      0.115462     ROP
#
#                    metabolite_pair  control_n  case_n
# 0                   ARG/ORN :: OXP       9347    4189
# 1                      C-10 :: ARG       9347    4189
# 2                    C-12:1 :: ARG       9347    4189
# 3                      C-16 :: C-5       9347    4189
# 4                  C-8/C-10 :: PHE       9347    4189
# ..                             ...        ...     ...
# 99   PHE/TYR :: FC/(C-16 + C-18:1)       7818    5718
# 100                  TYR :: C-18:1       7818    5718
# 101                   VAL :: C14:1       7818    5718
# 102                    XLE :: C-16       7818    5718
# 103                 XLE :: PHE/TYR       7818    5718
#
# [104 rows x 15 columns]

# %%
corr_df_counts['metabolite_pair'] = corr_df_counts[['metabolite_from', 'metabolite_to']].agg(' :: '.join, axis=1)

# %%
corr_df_counts
# Out:
#     metabolite_from       metabolite_to  case_spearman_rho     case_pval  \
# 0           ARG/ORN                 OXP           0.100741  6.149821e-11
# 1              C-10                 ARG           0.114193  1.166276e-13
# 2            C-12:1                 ARG           0.076605  6.834579e-07
# 3              C-16                 C-5           0.005384  7.275618e-01
# 4          C-8/C-10                 PHE          -0.002837  8.543761e-01
# ..              ...                 ...                ...           ...
# 99          PHE/TYR  FC/(C-16 + C-18:1)          -0.017385  1.887169e-01
# 100             TYR              C-18:1          -0.035964  6.529541e-03
# 101             VAL               C14:1           0.010213  4.400463e-01
# 102             XLE                C-16           0.012015  3.637084e-01
# 103             XLE             PHE/TYR          -0.002342  8.594474e-01
#
#      case_log10_pval  control_spearman_rho  control_pval  control_log10_pval  \
# 0          10.211138             -0.024086  1.097661e-01            0.959532
# 1          12.933199             -0.007928  5.986706e-01            0.222812
# 2           6.165288             -0.004699  7.550614e-01            0.122018
# 3           0.138130             -0.116305  8.762844e-15           14.057355
# 4           0.068351              0.053265  4.010653e-04            3.396785
# ..               ...                   ...           ...                 ...
# 99          0.724189              0.127542  1.690714e-17           16.771930
# 100         2.185117              0.005272  7.263622e-01            0.138847
# 101         0.356502             -0.083516  2.741576e-08            7.562000
# 102         0.439247             -0.098130  6.342991e-11           10.197706
# 103         0.065781              0.113119  4.637352e-14           13.333730
#
#      metabolite_pair_label  rho_diff  abs_rho_diff outcome  \
# 0                      NaN  0.076655      0.124827     BPD
# 1                      NaN  0.106265      0.122121     BPD
# 2                      NaN  0.071905      0.081304     BPD
# 3                      NaN -0.110921      0.121689     BPD
# 4                      NaN  0.050429      0.056102     BPD
# ..                     ...       ...           ...     ...
# 99                     NaN  0.110157      0.144927     ROP
# 100                    NaN -0.030692      0.041235     ROP
# 101                    NaN -0.073303      0.093729     ROP
# 102                    NaN -0.086115      0.110145     ROP
# 103                    NaN  0.110777      0.115462     ROP
#
#                    metabolite_pair  control_n  case_n
# 0                   ARG/ORN :: OXP       9347    4189
# 1                      C-10 :: ARG       9347    4189
# 2                    C-12:1 :: ARG       9347    4189
# 3                      C-16 :: C-5       9347    4189
# 4                  C-8/C-10 :: PHE       9347    4189
# ..                             ...        ...     ...
# 99   PHE/TYR :: FC/(C-16 + C-18:1)       7818    5718
# 100                  TYR :: C-18:1       7818    5718
# 101                   VAL :: C14:1       7818    5718
# 102                    XLE :: C-16       7818    5718
# 103                 XLE :: PHE/TYR       7818    5718
#
# [104 rows x 15 columns]

# %%
# Fisher's Z Transformation Test for Reporting Correlation Difference P Values
def fisher_z_test(rho1, n1, rho2, n2):
    """
    Test if two correlations are significantly different using Fisher's Z transformation
    
    Parameters:
    rho1: Spearman rho for cases
    n1: Sample size for cases
    rho2: Spearman rho for controls
    n2: Sample size for controls
    
    Returns:
    P value for difference in correlations
    """
    # Fisher's Z transformation
    z1 = np.arctanh(rho1)
    z2 = np.arctanh(rho2)
    
    # Standard error of the difference
    se_diff = np.sqrt(1/(n1-3) + 1/(n2-3))
    
    # Z statistic
    z_stat = (z1 - z2) / se_diff
    
    # Two-tailed P value
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))
    
    return p_value

corr_df_counts['disruption_pval'] = corr_df_counts.apply(
    lambda row: fisher_z_test(
        row['case_spearman_rho'], row['case_n'],
        row['control_spearman_rho'], row['control_n']
    ), axis=1
)

# %%
corr_df_counts['disruption_fdr'] = multipletests(corr_df_counts['disruption_pval'], method='fdr_bh')[1]
# Filter for significant disruptions
significant_disruptions = corr_df_counts[
    (corr_df_counts['disruption_fdr'] < 0.05) &
    (corr_df_counts['abs_rho_diff'] > 0.12)
]

# %%
corr_df_counts
# Out:
#     metabolite_from       metabolite_to  case_spearman_rho     case_pval  \
# 0           ARG/ORN                 OXP           0.100741  6.149821e-11
# 1              C-10                 ARG           0.114193  1.166276e-13
# 2            C-12:1                 ARG           0.076605  6.834579e-07
# 3              C-16                 C-5           0.005384  7.275618e-01
# 4          C-8/C-10                 PHE          -0.002837  8.543761e-01
# ..              ...                 ...                ...           ...
# 99          PHE/TYR  FC/(C-16 + C-18:1)          -0.017385  1.887169e-01
# 100             TYR              C-18:1          -0.035964  6.529541e-03
# 101             VAL               C14:1           0.010213  4.400463e-01
# 102             XLE                C-16           0.012015  3.637084e-01
# 103             XLE             PHE/TYR          -0.002342  8.594474e-01
#
#      case_log10_pval  control_spearman_rho  control_pval  control_log10_pval  \
# 0          10.211138             -0.024086  1.097661e-01            0.959532
# 1          12.933199             -0.007928  5.986706e-01            0.222812
# 2           6.165288             -0.004699  7.550614e-01            0.122018
# 3           0.138130             -0.116305  8.762844e-15           14.057355
# 4           0.068351              0.053265  4.010653e-04            3.396785
# ..               ...                   ...           ...                 ...
# 99          0.724189              0.127542  1.690714e-17           16.771930
# 100         2.185117              0.005272  7.263622e-01            0.138847
# 101         0.356502             -0.083516  2.741576e-08            7.562000
# 102         0.439247             -0.098130  6.342991e-11           10.197706
# 103         0.065781              0.113119  4.637352e-14           13.333730
#
#      metabolite_pair_label  rho_diff  abs_rho_diff outcome  \
# 0                      NaN  0.076655      0.124827     BPD
# 1                      NaN  0.106265      0.122121     BPD
# 2                      NaN  0.071905      0.081304     BPD
# 3                      NaN -0.110921      0.121689     BPD
# 4                      NaN  0.050429      0.056102     BPD
# ..                     ...       ...           ...     ...
# 99                     NaN  0.110157      0.144927     ROP
# 100                    NaN -0.030692      0.041235     ROP
# 101                    NaN -0.073303      0.093729     ROP
# 102                    NaN -0.086115      0.110145     ROP
# 103                    NaN  0.110777      0.115462     ROP
#
#                    metabolite_pair  control_n  case_n  disruption_pval  \
# 0                   ARG/ORN :: OXP       9347    4189     1.693623e-11
# 1                      C-10 :: ARG       9347    4189     4.310463e-11
# 2                    C-12:1 :: ARG       9347    4189     1.189068e-05
# 3                      C-16 :: C-5       9347    4189     4.987033e-11
# 4                  C-8/C-10 :: PHE       9347    4189     2.534726e-03
# ..                             ...        ...     ...              ...
# 99   PHE/TYR :: FC/(C-16 + C-18:1)       7818    5718     0.000000e+00
# 100                  TYR :: C-18:1       7818    5718     1.778592e-02
# 101                   VAL :: C14:1       7818    5718     6.799497e-08
# 102                    XLE :: C-16       7818    5718     2.202079e-10
# 103                 XLE :: PHE/TYR       7818    5718     2.706169e-11
#
#      disruption_fdr
# 0      9.785377e-11
# 1      1.867867e-10
# 2      1.766615e-05
# 3      2.074606e-10
# 4      2.929017e-03
# ..              ...
# 99     0.000000e+00
# 100    1.926808e-02
# 101    1.571439e-07
# 102    7.633872e-10
# 103    1.407208e-10
#
# [104 rows x 17 columns]

# %%
significant_disruptions
# Out:
#    metabolite_from       metabolite_to  case_spearman_rho     case_pval  \
# 0          ARG/ORN                 OXP           0.100741  6.149821e-11
# 1             C-10                 ARG           0.114193  1.166276e-13
# 3             C-16                 C-5           0.005384  7.275618e-01
# 9              ORN                C-10           0.126851  1.562540e-16
# 13             OXP                 C-5           0.125302  3.646447e-16
# 14             PHE                C-10           0.102213  3.217458e-11
# 18         PHE/TYR                 C-4          -0.111129  5.206502e-13
# 19         PHE/TYR                 C-5          -0.026430  8.718869e-02
# 20         PHE/TYR  FC/(C-16 + C-18:1)          -0.034909  2.385041e-02
# 21         PHE/TYR                 PHE          -0.002828  8.548048e-01
# 23             XLE                C-16           0.023618  1.264236e-01
# 37             OXP                 C-5           0.136396  3.395893e-19
# 40         PHE/TYR                C-16           0.110569  4.363929e-13
# 41         PHE/TYR                 C-4          -0.101266  3.359081e-11
# 42         PHE/TYR                 C-5          -0.011516  4.524054e-01
# 43         PHE/TYR  FC/(C-16 + C-18:1)          -0.026969  7.840458e-02
# 48             XLE             PHE/TYR          -0.017655  2.493070e-01
# 49         ARG/ORN                C-14           0.007885  7.650927e-01
# 52         ARG/ORN                 OXP           0.096621  2.398443e-04
# 53            C-10                 ARG           0.112844  1.751024e-05
# 55            C-12                 ARG           0.050565  5.514178e-02
# 57            C-14                 C-5           0.073285  5.400706e-03
# 58            C-16                 C-5           0.005434  8.368594e-01
# 59          C-18:2                C-12           0.005861  8.242358e-01
# 63         CIT/ARG                C-12          -0.001674  9.494207e-01
# 65             CIT               C14:1           0.132293  4.589325e-07
# 66         LEU/ALA             ARG/ORN          -0.006720  7.989851e-01
# 68         LEU/ALA  FC/(C-16 + C-18:1)          -0.034504  1.908560e-01
# 69             ORN                C-10           0.112310  1.920348e-05
# 72             OXP                 C-5           0.198845  2.225653e-14
# 77         PHE/TYR                 C-5          -0.017852  4.986900e-01
# 78         PHE/TYR  FC/(C-16 + C-18:1)          -0.007027  7.900244e-01
# 80             VAL               C14:1           0.061511  1.960291e-02
# 81             XLE                C-16           0.027861  2.909464e-01
# 82             XLE             PHE/TYR          -0.010244  6.978556e-01
# 88         LEU/ALA  FC/(C-16 + C-18:1)          -0.002587  8.449404e-01
# 92             OXP                 C-5           0.113409  7.274106e-18
# 97         PHE/TYR                 C-4          -0.111408  2.737270e-17
# 98         PHE/TYR                 C-5          -0.003146  8.119942e-01
# 99         PHE/TYR  FC/(C-16 + C-18:1)          -0.017385  1.887169e-01
#
#     case_log10_pval  control_spearman_rho  control_pval  control_log10_pval  \
# 0         10.211138             -0.024086  1.097661e-01            0.959532
# 1         12.933199             -0.007928  5.986706e-01            0.222812
# 3          0.138130             -0.116305  8.762844e-15           14.057355
# 9         15.806169             -0.009654  5.215866e-01            0.282674
# 13        15.438130             -0.026064  8.351270e-02            1.078247
# 14        10.492487             -0.020279  1.781692e-01            0.749167
# 18        12.283454              0.034702  2.118795e-02            1.673911
# 19         1.059540              0.148436  3.166602e-23           22.499406
# 20         1.622504              0.127542  1.690714e-17           16.771930
# 21         0.068133              0.121362  5.653958e-16           15.247647
# 23         0.898172             -0.098130  6.342991e-11           10.197706
# 37        18.469046             -0.026064  8.351270e-02            1.078247
# 40        12.360122             -0.036669  1.487709e-02            1.827482
# 41        10.473780              0.034702  2.118795e-02            1.673911
# 42         0.344472              0.148436  3.166602e-23           22.499406
# 43         1.105659              0.127542  1.690714e-17           16.771930
# 48         0.603266              0.113119  4.637352e-14           13.333730
# 49         0.116286             -0.122361  3.245395e-16           15.488732
# 52         3.620071             -0.024086  1.097661e-01            0.959532
# 53         4.756708             -0.007928  5.986706e-01            0.222812
# 55         1.258519             -0.133747  4.170095e-19           18.379854
# 57         2.267550             -0.099577  3.302740e-11           10.481126
# 58         0.077348             -0.116305  8.762844e-15           14.057355
# 59         0.083949             -0.146611  1.088200e-22           21.963291
# 63         0.022541              0.145409  2.431031e-22           21.614210
# 65         6.338251             -0.026898  7.409420e-02            1.130216
# 66         0.097461              0.113565  3.684481e-14           13.433624
# 68         0.719294              0.142041  2.231643e-21           20.651375
# 69         4.716620             -0.009654  5.215866e-01            0.282674
# 72        13.652543             -0.026064  8.351270e-02            1.078247
# 77         0.302169              0.148436  3.166602e-23           22.499406
# 78         0.102359              0.127542  1.690714e-17           16.771930
# 80         1.707679             -0.083516  2.741576e-08            7.562000
# 81         0.536187             -0.098130  6.342991e-11           10.197706
# 82         0.156234              0.113119  4.637352e-14           13.333730
# 88         0.073174              0.142041  2.231643e-21           20.651375
# 92        17.138220             -0.026064  8.351270e-02            1.078247
# 97        16.562682              0.034702  2.118795e-02            1.673911
# 98         0.090447              0.148436  3.166602e-23           22.499406
# 99         0.724189              0.127542  1.690714e-17           16.771930
#
#     metabolite_pair_label  rho_diff  abs_rho_diff outcome  \
# 0                     NaN  0.076655      0.124827     BPD
# 1                     NaN  0.106265      0.122121     BPD
# 3                     NaN -0.110921      0.121689     BPD
# 9                     NaN  0.117197      0.136505     BPD
# 13                    NaN  0.099238      0.151366     BPD
# 14                    NaN  0.081934      0.122492     BPD
# 18                    NaN -0.076427      0.145831     BPD
# 19                    NaN  0.122006      0.174866     BPD
# 20                    NaN  0.092633      0.162452     BPD
# 21                    NaN  0.118534      0.124190     BPD
# 23                    NaN -0.074512      0.121748     BPD
# 37                    NaN  0.110332      0.162460     IVH
# 40                    NaN  0.073900      0.147238     IVH
# 41                    NaN -0.066564      0.135968     IVH
# 42                    NaN  0.136920      0.159952     IVH
# 43                    NaN  0.100574      0.154511     IVH
# 48                    NaN  0.095464      0.130775     IVH
# 49                    NaN -0.114476      0.130245     NEC
# 52                    NaN  0.072535      0.120707     NEC
# 53                    NaN  0.104916      0.120772     NEC
# 55                    NaN -0.083183      0.184312     NEC
# 57                    NaN -0.026291      0.172862     NEC
# 58                    NaN -0.110871      0.121739     NEC
# 59                    NaN -0.140750      0.152472     NEC
# 63                    NaN  0.143735      0.147083     NEC
# 65                    NaN  0.105395      0.159190     NEC
# 66                    NaN  0.106844      0.120285     NEC
# 68                    NaN  0.107536      0.176545     NEC
# 69                    NaN  0.102656      0.121964     NEC
# 72                    NaN  0.172781      0.224909     NEC
# 77                    NaN  0.130585      0.166288     NEC
# 78                    NaN  0.120516      0.134569     NEC
# 80                    NaN -0.022006      0.145027     NEC
# 81                    NaN -0.070269      0.125991     NEC
# 82                    NaN  0.102875      0.123364     NEC
# 88                    NaN  0.139454      0.144628     ROP
# 92                    NaN  0.087345      0.139473     ROP
# 97                    NaN -0.076706      0.146110     ROP
# 98                    NaN  0.145290      0.151583     ROP
# 99                    NaN  0.110157      0.144927     ROP
#
#                   metabolite_pair  control_n  case_n  disruption_pval  \
# 0                  ARG/ORN :: OXP       9347    4189     1.693623e-11
# 1                     C-10 :: ARG       9347    4189     4.310463e-11
# 3                     C-16 :: C-5       9347    4189     4.987033e-11
# 9                     ORN :: C-10       9347    4189     1.625367e-13
# 13                     OXP :: C-5       9347    4189     2.220446e-16
# 14                    PHE :: C-10       9347    4189     3.963496e-11
# 18                 PHE/TYR :: C-4       9347    4189     3.552714e-15
# 19                 PHE/TYR :: C-5       9347    4189     0.000000e+00
# 20  PHE/TYR :: FC/(C-16 + C-18:1)       9347    4189     0.000000e+00
# 21                 PHE/TYR :: PHE       9347    4189     1.950484e-11
# 23                    XLE :: C-16       9347    4189     5.262057e-11
# 37                     OXP :: C-5       9276    4260     0.000000e+00
# 40                PHE/TYR :: C-16       9276    4260     1.554312e-15
# 41                 PHE/TYR :: C-4       9276    4260     1.787459e-13
# 42                 PHE/TYR :: C-5       9276    4260     0.000000e+00
# 43  PHE/TYR :: FC/(C-16 + C-18:1)       9276    4260     0.000000e+00
# 48                 XLE :: PHE/TYR       9276    4260     1.339817e-12
# 49                ARG/ORN :: C-14      12097    1439     2.753291e-06
# 52                 ARG/ORN :: OXP      12097    1439     1.453738e-05
# 53                    C-10 :: ARG      12097    1439     1.397598e-05
# 55                    C-12 :: ARG      12097    1439     3.271294e-11
# 57                    C-14 :: C-5      12097    1439     5.306993e-10
# 58                    C-16 :: C-5      12097    1439     1.184039e-05
# 59                 C-18:2 :: C-12      12097    1439     3.781401e-08
# 63                CIT/ARG :: C-12      12097    1439     1.115809e-07
# 65                   CIT :: C14:1      12097    1439     9.953409e-09
# 66             LEU/ALA :: ARG/ORN      12097    1439     1.510857e-05
# 68  LEU/ALA :: FC/(C-16 + C-18:1)      12097    1439     2.014038e-10
# 69                    ORN :: C-10      12097    1439     1.150966e-05
# 72                     OXP :: C-5      12097    1439     4.440892e-16
# 77                 PHE/TYR :: C-5      12097    1439     2.006441e-09
# 78  PHE/TYR :: FC/(C-16 + C-18:1)      12097    1439     1.258105e-06
# 80                   VAL :: C14:1      12097    1439     1.932895e-07
# 81                    XLE :: C-16      12097    1439     6.024830e-06
# 82                 XLE :: PHE/TYR      12097    1439     9.112993e-06
# 88  LEU/ALA :: FC/(C-16 + C-18:1)       7818    5718     0.000000e+00
# 92                     OXP :: C-5       7818    5718     8.881784e-16
# 97                 PHE/TYR :: C-4       7818    5718     0.000000e+00
# 98                 PHE/TYR :: C-5       7818    5718     0.000000e+00
# 99  PHE/TYR :: FC/(C-16 + C-18:1)       7818    5718     0.000000e+00
#
#     disruption_fdr
# 0     9.785377e-11
# 1     1.867867e-10
# 3     2.074606e-10
# 9     1.126921e-12
# 13    2.309264e-15
# 14    1.828606e-10
# 18    2.639159e-14
# 19    0.000000e+00
# 20    0.000000e+00
# 21    1.067633e-10
# 23    2.104823e-10
# 37    0.000000e+00
# 40    1.243450e-14
# 41    1.161848e-12
# 42    0.000000e+00
# 43    0.000000e+00
# 48    8.196528e-12
# 49    4.772372e-06
# 52    2.043091e-05
# 53    1.991099e-05
# 55    1.620070e-10
# 57    1.576935e-09
# 58    1.766615e-05
# 59    9.145715e-08
# 63    2.417586e-07
# 65    2.524767e-08
# 66    2.095056e-05
# 68    7.222756e-10
# 69    1.760301e-05
# 72    4.198662e-15
# 77    5.796386e-09
# 78    2.295490e-06
# 80    4.102471e-07
# 81    9.790348e-06
# 82    1.435987e-05
# 88    0.000000e+00
# 92    7.697546e-15
# 97    0.000000e+00
# 98    0.000000e+00
# 99    0.000000e+00

# %%
eval_df = corr_df_counts[['metabolite_pair', 'outcome', 'case_pval', 'control_pval', 'abs_rho_diff', 'disruption_fdr']].sort_values('metabolite_pair')
eval_df
# Out:
#       metabolite_pair outcome     case_pval  control_pval  abs_rho_diff  \
# 49    ARG/ORN :: C-14     NEC  7.650927e-01  3.245395e-16      0.130245
# 50   ARG/ORN :: C-8:1     NEC  9.214281e-01  5.432993e-05      0.063327
# 51     ARG/ORN :: ORN     NEC  7.002675e-01  4.265489e-07      0.086184
# 83     ARG/ORN :: OXP     ROP  3.326055e-09  1.097661e-01      0.102165
# 52     ARG/ORN :: OXP     NEC  2.398443e-04  1.097661e-01      0.120707
# ..                ...     ...           ...           ...           ...
# 23        XLE :: C-16     BPD  1.264236e-01  6.342991e-11      0.121748
# 48     XLE :: PHE/TYR     IVH  2.493070e-01  4.637352e-14      0.130775
# 82     XLE :: PHE/TYR     NEC  6.978556e-01  4.637352e-14      0.123364
# 24     XLE :: PHE/TYR     BPD  8.688624e-01  4.637352e-14      0.115671
# 103    XLE :: PHE/TYR     ROP  8.594474e-01  4.637352e-14      0.115462
#
#      disruption_fdr
# 49     4.772372e-06
# 50     2.478341e-02
# 51     2.341720e-03
# 83     1.126679e-08
# 52     2.043091e-05
# ..              ...
# 23     2.104823e-10
# 48     8.196528e-12
# 82     1.435987e-05
# 24     1.358561e-09
# 103    1.407208e-10
#
# [104 rows x 6 columns]

# %%
counts_df = eval_df.groupby('metabolite_pair').count().sort_values(['outcome'], ascending=False)
top_counts = counts_df.query('outcome == 4')
counts_df
# Out:
#                                outcome  case_pval  control_pval  abs_rho_diff  \
# metabolite_pair
# XLE :: PHE/TYR                       4          4             4             4
# PHE/TYR :: FC/(C-16 + C-18:1)        4          4             4             4
# ORN :: C-10                          4          4             4             4
# OXP :: C-5                           4          4             4             4
# PHE :: C-10                          4          4             4             4
# PHE/TYR :: ARG                       4          4             4             4
# PHE/TYR :: C-16                      4          4             4             4
# PHE/TYR :: C-4                       4          4             4             4
# CIT/ARG :: C-10                      4          4             4             4
# CIT :: C14:1                         4          4             4             4
# PHE/TYR :: C-5                       4          4             4             4
# TYR :: C-18:1                        4          4             4             4
# C-12:1 :: ARG                        4          4             4             4
# C-10 :: ARG                          4          4             4             4
# ARG/ORN :: OXP                       4          4             4             4
# XLE :: C-16                          4          4             4             4
# ORN/CIT :: C-10                      4          4             4             4
# C-16 :: C-5                          3          3             3             3
# VAL :: C14:1                         3          3             3             3
# ORN :: C14:1                         2          2             2             2
# C-14 :: C-5                          2          2             2             2
# PHE/TYR :: C-2                       2          2             2             2
# LEU/ALA :: FC/(C-16 + C-18:1)        2          2             2             2
# PHE/TYR :: PHE                       1          1             1             1
# VAL :: C-14OH                        1          1             1             1
# ORN/CIT :: FC                        1          1             1             1
# ORN/CIT :: C-14OH                    1          1             1             1
# ARG/ORN :: C-14                      1          1             1             1
# ORN :: C-14OH                        1          1             1             1
# C-8/C-10 :: PHE                      1          1             1             1
# ARG/ORN :: ORN                       1          1             1             1
# C-12 :: ARG                          1          1             1             1
# C-14:1/C-12:1 :: C-2                 1          1             1             1
# C-18:2 :: C-12                       1          1             1             1
# C-18:2 :: C-5DC                      1          1             1             1
# C-8/C-10 :: OXP                      1          1             1             1
# CIT/ARG :: C-12                      1          1             1             1
# LEU/ALA :: C-18                      1          1             1             1
# CIT/ARG :: C-3/C-2                   1          1             1             1
# CIT/ARG :: C14:1                     1          1             1             1
# FC/(C-16 + C-18:1) :: ORN            1          1             1             1
# LEU/ALA :: ARG/ORN                   1          1             1             1
# LEU/ALA :: C-10                      1          1             1             1
# ARG/ORN :: C-8:1                     1          1             1             1
# LEU/ALA :: C-16OH                    1          1             1             1
#
#                                disruption_fdr
# metabolite_pair
# XLE :: PHE/TYR                              4
# PHE/TYR :: FC/(C-16 + C-18:1)               4
# ORN :: C-10                                 4
# OXP :: C-5                                  4
# PHE :: C-10                                 4
# PHE/TYR :: ARG                              4
# PHE/TYR :: C-16                             4
# PHE/TYR :: C-4                              4
# CIT/ARG :: C-10                             4
# CIT :: C14:1                                4
# PHE/TYR :: C-5                              4
# TYR :: C-18:1                               4
# C-12:1 :: ARG                               4
# C-10 :: ARG                                 4
# ARG/ORN :: OXP                              4
# XLE :: C-16                                 4
# ORN/CIT :: C-10                             4
# C-16 :: C-5                                 3
# VAL :: C14:1                                3
# ORN :: C14:1                                2
# C-14 :: C-5                                 2
# PHE/TYR :: C-2                              2
# LEU/ALA :: FC/(C-16 + C-18:1)               2
# PHE/TYR :: PHE                              1
# VAL :: C-14OH                               1
# ORN/CIT :: FC                               1
# ORN/CIT :: C-14OH                           1
# ARG/ORN :: C-14                             1
# ORN :: C-14OH                               1
# C-8/C-10 :: PHE                             1
# ARG/ORN :: ORN                              1
# C-12 :: ARG                                 1
# C-14:1/C-12:1 :: C-2                        1
# C-18:2 :: C-12                              1
# C-18:2 :: C-5DC                             1
# C-8/C-10 :: OXP                             1
# CIT/ARG :: C-12                             1
# LEU/ALA :: C-18                             1
# CIT/ARG :: C-3/C-2                          1
# CIT/ARG :: C14:1                            1
# FC/(C-16 + C-18:1) :: ORN                   1
# LEU/ALA :: ARG/ORN                          1
# LEU/ALA :: C-10                             1
# ARG/ORN :: C-8:1                            1
# LEU/ALA :: C-16OH                           1

# %%
top_counts_df = eval_df[eval_df['metabolite_pair'].isin(top_counts.index)]
top_counts_df = top_counts_df.sort_values(['metabolite_pair', 'outcome'])
top_counts_df.to_csv(
    f"./intermediate_output/{nb_save_prefix}_common_metabolite_pairs.csv",
    index=False)
top_counts_df
# Out:
#     metabolite_pair outcome     case_pval  control_pval  abs_rho_diff  \
# 0    ARG/ORN :: OXP     BPD  6.149821e-11  1.097661e-01      0.124827
# 25   ARG/ORN :: OXP     IVH  2.395023e-09  1.097661e-01      0.115308
# 52   ARG/ORN :: OXP     NEC  2.398443e-04  1.097661e-01      0.120707
# 83   ARG/ORN :: OXP     ROP  3.326055e-09  1.097661e-01      0.102165
# 1       C-10 :: ARG     BPD  1.166276e-13  5.986706e-01      0.122121
# ..              ...     ...           ...           ...           ...
# 102     XLE :: C-16     ROP  3.637084e-01  6.342991e-11      0.110145
# 24   XLE :: PHE/TYR     BPD  8.688624e-01  4.637352e-14      0.115671
# 48   XLE :: PHE/TYR     IVH  2.493070e-01  4.637352e-14      0.130775
# 82   XLE :: PHE/TYR     NEC  6.978556e-01  4.637352e-14      0.123364
# 103  XLE :: PHE/TYR     ROP  8.594474e-01  4.637352e-14      0.115462
#
#      disruption_fdr
# 0      9.785377e-11
# 25     1.358561e-09
# 52     2.043091e-05
# 83     1.126679e-08
# 1      1.867867e-10
# ..              ...
# 102    7.633872e-10
# 24     1.358561e-09
# 48     8.196528e-12
# 82     1.435987e-05
# 103    1.407208e-10
#
# [68 rows x 6 columns]

# %%
var_df = top_counts_df.groupby('metabolite_pair').var(numeric_only=True)
var_df.sort_values('abs_rho_diff')
# Out:
#                                   case_pval  control_pval  abs_rho_diff
# metabolite_pair
# C-12:1 :: ARG                  5.013419e-06           0.0      0.000041
# XLE :: C-16                    9.952703e-03           0.0      0.000050
# XLE :: PHE/TYR                 8.439666e-02           0.0      0.000053
# PHE/TYR :: C-5                 8.813878e-02           0.0      0.000097
# ARG/ORN :: OXP                 1.438109e-08           0.0      0.000097
# PHE/TYR :: FC/(C-16 + C-18:1)  1.247768e-01           0.0      0.000145
# C-10 :: ARG                    7.665134e-11           0.0      0.000174
# CIT/ARG :: C-10                6.871349e-07           0.0      0.000215
# PHE/TYR :: C-4                 1.797083e-06           0.0      0.000231
# PHE/TYR :: ARG                 5.930776e-03           0.0      0.000314
# ORN :: C-10                    9.180710e-11           0.0      0.000368
# PHE :: C-10                    5.398915e-05           0.0      0.000380
# ORN/CIT :: C-10                2.687418e-03           0.0      0.000442
# TYR :: C-18:1                  1.883642e-02           0.0      0.000550
# CIT :: C14:1                   7.408996e-11           0.0      0.001112
# PHE/TYR :: C-16                6.683504e-03           0.0      0.001217
# OXP :: C-5                     1.224902e-28           0.0      0.001450

# %% [markdown]
# # Analytic Approach for Outcome-Specific Disruptions

# %%
specific_counts = counts_df.query('outcome == 1')

# %%
specific_edges = eval_df[eval_df['metabolite_pair'].isin(specific_counts.index)]
specific_edges = specific_edges.sort_values(["outcome", "disruption_fdr"])
specific_edges
# Out:
#               metabolite_pair outcome  case_pval  control_pval  abs_rho_diff  \
# 21             PHE/TYR :: PHE     BPD   0.854805  5.653958e-16      0.124190
# 8             LEU/ALA :: C-10     BPD   0.966242  2.524887e-10      0.095651
# 10              ORN :: C-14OH     BPD   0.405873  4.529318e-07      0.088700
# 6            CIT/ARG :: C14:1     BPD   0.716442  4.243133e-06      0.074782
# 12          ORN/CIT :: C-14OH     BPD   0.963127  8.266118e-06      0.067770
# 4             C-8/C-10 :: PHE     BPD   0.854376  4.010653e-04      0.056102
# 46              VAL :: C-14OH     IVH   0.819020  8.771005e-07      0.077445
# 32  FC/(C-16 + C-18:1) :: ORN     IVH   0.789873  1.117386e-06      0.077309
# 33            LEU/ALA :: C-18     IVH   0.740413  6.633338e-03      0.045948
# 55                C-12 :: ARG     NEC   0.055142  4.170095e-19      0.184312
# 59             C-18:2 :: C-12     NEC   0.824236  1.088200e-22      0.152472
# 63            CIT/ARG :: C-12     NEC   0.949421  2.431031e-22      0.147083
# 49            ARG/ORN :: C-14     NEC   0.765093  3.245395e-16      0.130245
# 66         LEU/ALA :: ARG/ORN     NEC   0.798985  3.684481e-14      0.120285
# 61            C-8/C-10 :: OXP     NEC   0.900105  1.141305e-14      0.119118
# 51             ARG/ORN :: ORN     NEC   0.700267  4.265489e-07      0.086184
# 67          LEU/ALA :: C-16OH     NEC   0.758015  1.189020e-05      0.074007
# 50           ARG/ORN :: C-8:1     NEC   0.921428  5.432993e-05      0.063327
# 64         CIT/ARG :: C-3/C-2     NEC   0.803813  2.978872e-04      0.060988
# 56       C-14:1/C-12:1 :: C-2     NEC   0.679562  3.260219e-03      0.055189
# 60            C-18:2 :: C-5DC     NEC   0.952773  1.531871e-03      0.049257
# 71              ORN/CIT :: FC     NEC   0.999149  3.744231e-03      0.043669
#
#     disruption_fdr
# 21    1.067633e-10
# 8     5.182731e-07
# 10    3.190207e-06
# 6     7.171641e-05
# 12    3.218464e-04
# 4     2.929017e-03
# 46    3.759684e-05
# 32    3.837252e-05
# 33    1.440907e-02
# 55    1.620070e-10
# 59    9.145715e-08
# 63    2.417586e-07
# 49    4.772372e-06
# 66    2.095056e-05
# 61    2.485221e-05
# 51    2.341720e-03
# 67    8.968280e-03
# 50    2.478341e-02
# 64    3.050380e-02
# 56    4.980784e-02
# 60    7.968903e-02
# 71    1.185990e-01

# %%
specific_edges.to_csv(f"intermediate_output/{nb_save_prefix}_outcome_specific_edges.csv", index=False)
